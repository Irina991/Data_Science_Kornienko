# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# Задание 1

# %%
x = [1,2,3,4,5,6,7]
y = [3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# Задание 2

# %%
from pylab import rcParams

# %%
t = np.linspace(0, 10, 51)
t
# Out:
# array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ,
#         2.2,  2.4,  2.6,  2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,
#         4.4,  4.6,  4.8,  5. ,  5.2,  5.4,  5.6,  5.8,  6. ,  6.2,  6.4,
#         6.6,  6.8,  7. ,  7.2,  7.4,  7.6,  7.8,  8. ,  8.2,  8.4,  8.6,
#         8.8,  9. ,  9.2,  9.4,  9.6,  9.8, 10. ])

# %%
f = np.cos(t)

# %%
f
# Out:
# array([ 1.        ,  0.98006658,  0.92106099,  0.82533561,  0.69670671,
#         0.54030231,  0.36235775,  0.16996714, -0.02919952, -0.22720209,
#        -0.41614684, -0.58850112, -0.73739372, -0.85688875, -0.94222234,
#        -0.9899925 , -0.99829478, -0.96679819, -0.89675842, -0.79096771,
#        -0.65364362, -0.49026082, -0.30733287, -0.11215253,  0.08749898,
#         0.28366219,  0.46851667,  0.63469288,  0.77556588,  0.88551952,
#         0.96017029,  0.9965421 ,  0.99318492,  0.95023259,  0.86939749,
#         0.75390225,  0.60835131,  0.43854733,  0.25125984,  0.05395542,
#        -0.14550003, -0.33915486, -0.51928865, -0.67872005, -0.81109301,
#        -0.91113026, -0.97484362, -0.99969304, -0.98468786, -0.93042627,
#        -0.83907153])

# %%
plt.plot(t, f, color = 'green')

# %%
# %config inLineBackend.figure_format = 'svg'
plt.plot(t, f)
plt.axis([0.5, 9.5, -2.5, 2.5])
plt.title('График t(f)', fontsize = 16, fontweight = 'bold', color = 'DarkRed')
plt.xlabel('переменная t')
plt.ylabel('переменная f')
plt.show()

# %% [markdown]
# Задание 3

# %%
x= np.linspace(-3, 3, 51)
y1 = x**2
y2 = 2 * x + 0.5
y3 = -3 * x - 1.5
y4 = np.sin(x)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
ax1, ax2, ax3, ax4 = ax.flatten()
ax1.plot(x, y1)
ax1.set_title('График (x, y1)')
ax1.set_xlim([-5, 5])
ax2.plot(x, y2)
ax2.set_title('График (x, y2)')
ax2.set_xlim([-5, 5])
ax3.plot(x, y3)
ax3.set_title('График (x, y3)')
ax3.set_xlim([-5, 5])
ax4.plot(x, y4)
ax4.set_title('График (x, y4)')
ax4.set_xlim([-5, 5])
fig.set_size_inches(8, 6)
plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %% [markdown]
# Задание 4

# %%
import pandas as pd
# !C:\Users\link1\Desktop\Pandas/creditcard.csv
fixed_df = pd.read_csv('Desktop\Pandas/creditcard.csv')

# %%
fixed_df

# %%
# fixed_df['V1'].value_counts()
fixed_df['Class'].value_counts()

# %%
graf = pd.Series(fixed_df['Class'].value_counts())

# %%
graf
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
graf.plot('bar')
# plt.plot(graf)
plt.yscale(value = 'log')

# %%
mass1 = fixed_df.loc[fixed_df['Class'] == 0, 'V1'].values

# %%
mass1

# %%
mass2 = fixed_df.loc[fixed_df['Class'] == 1, 'V1'].values

# %%
mass2

# %%
common = pd.Series(mass1)
fraud = pd.Series(mass2)

# %%
common
# Out:
# 0         -1.359807
# 1          1.191857
# 2         -1.358354
# 3         -0.966272
# 4         -1.158233
# 5         -0.425966
# 6          1.229658
# 7         -0.644269
# 8         -0.894286
# 9         -0.338262
# 10         1.449044
# 11         0.384978
# 12         1.249999
# 13         1.069374
# 14        -2.791855
# 15        -0.752417
# 16         1.103215
# 17        -0.436905
# 18        -5.401258
# 19         1.492936
# 20         0.694885
# 21         0.962496
# 22         1.166616
# 23         0.247491
# 24        -1.946525
# 25        -2.074295
# 26         1.173285
# 27         1.322707
# 28        -0.414289
# 29         1.059387
#             ...
# 284285     2.079137
# 284286    -0.764523
# 284287     1.975178
# 284288    -1.727503
# 284289    -1.139015
# 284290    -0.268061
# 284291    -1.796092
# 284292    -0.669662
# 284293     0.032887
# 284294    -2.076175
# 284295    -1.029719
# 284296     2.007418
# 284297    -0.446951
# 284298    -0.515513
# ...

# %%
common_graph = plt.hist(common, bins=20)
fraud_graph = plt.hist(fraud, bins=20, color = 'green')
plt.yscale(value = 'log')
plt.show()
